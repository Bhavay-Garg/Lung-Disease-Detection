# %%
! git clone https://github.com/Bhavay-Garg/Lung-Disease-Detection.git
# Out:
# fatal: destination path 'Lung-Disease-Detection' already exists and is not an empty directory.

# %%
from tensorflow.keras.applications import EfficientNetB3
model = EfficientNetB3(include_top=False, weights='imagenet')

# %%
IMG_SIZE = 300

# %%
import tensorflow as tf

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    print("Device:", tpu.master())
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# Not connected to a TPU runtime. Using CPU/GPU strategy

# %%
import tensorflow_datasets as tfds

batch_size = 16

builder = tfds.ImageFolder('/content/Lung-Disease-Detection/Dataset')


train_ds=ds = builder.as_dataset(split='train', shuffle_files=True,as_supervised=True)
test_ds=ds = builder.as_dataset(split='test', shuffle_files=True,as_supervised=True)
builder.info
# Out:
# tfds.core.DatasetInfo(
#     name='image_folder',
#     full_name='image_folder/1.0.0',
#     description="""
#     Generic image classification dataset.
#     """,
#     homepage='https://www.tensorflow.org/datasets/catalog/image_folder',
#     data_path='/root/tensorflow_datasets/image_folder/1.0.0',
#     file_format=tfrecord,
#     download_size=Unknown size,
#     dataset_size=Unknown size,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=uint8),
#         'image/filename': Text(shape=(), dtype=string),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=5),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=2025, num_shards=1>,
#         'train': <SplitInfo num_examples=6054, num_shards=1>,
#         'val': <SplitInfo num_examples=2016, num_shards=1>,
#     },
#     citation="""""",
# )

# %%
tfds.show_examples(train_ds, builder.info)

# %%
size = (IMG_SIZE, IMG_SIZE)
NUM_CLASSES=5
train_ds = train_ds.map(lambda image, label: (tf.image.resize(image, size), label))
test_ds = test_ds.map(lambda image, label: (tf.image.resize(image, size), label))

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


train_ds = train_ds.map(
    input_preprocess, num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.batch(batch_size=batch_size, drop_remainder=True)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

test_ds = test_ds.map(input_preprocess)
test_ds = test_ds.batch(batch_size=batch_size, drop_remainder=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
    [
        layers.RandomRotation(factor=0.15),
        layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
        layers.RandomFlip(),
        layers.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3,min_delta=0.0001)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkPoint = ModelCheckpoint('best_model_2.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# %%
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras import layers

with strategy.scope():
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    outputs = EfficientNetB3(include_top=True, weights=None, classes=5)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(
        optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )

model.summary()

epochs = 30  
hist = model.fit(train_ds, epochs=epochs, validation_data=test_ds, verbose=2, callbacks=[checkPoint])
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 300, 300, 3)]     0
#
#  img_augmentation (Sequentia  (None, 300, 300, 3)      0
#  l)
#
#  efficientnetb3 (Functional)  (None, 5)                10791220
#
# =================================================================
# Total params: 10,791,220
# Trainable params: 10,703,917
# Non-trainable params: 87,303
# _________________________________________________________________
# Epoch 1/30
#
# Epoch 1: val_loss improved from inf to 2.43371, saving model to best_model_2.h5
# 378/378 - 263s - loss: 2.0604 - accuracy: 0.4345 - val_loss: 2.4337 - val_accuracy: 0.2312 - 263s/epoch - 696ms/step
# Epoch 2/30
#
# Epoch 2: val_loss improved from 2.43371 to 1.26388, saving model to best_model_2.h5
# 378/378 - 191s - loss: 1.1348 - accuracy: 0.5794 - val_loss: 1.2639 - val_accuracy: 0.6047 - 191s/epoch - 506ms/step
# Epoch 3/30
#
# Epoch 3: val_loss did not improve from 1.26388
# 378/378 - 191s - loss: 0.9288 - accuracy: 0.6273 - val_loss: 3.9907 - val_accuracy: 0.3279 - 191s/epoch - 504ms/step
# Epoch 4/30
#
# Epoch 4: val_loss did not improve from 1.26388
# 378/378 - 189s - loss: 0.9291 - accuracy: 0.6354 - val_loss: 2.9062 - val_accuracy: 0.2133 - 189s/epoch - 501ms/step
# Epoch 5/30
#
# Epoch 5: val_loss improved from 1.26388 to 0.76971, saving model to best_model_2.h5
# 378/378 - 191s - loss: 0.8063 - accuracy: 0.6691 - val_loss: 0.7697 - val_accuracy: 0.6969 - 191s/epoch - 506ms/step
# Epoch 6/30
#
# Epoch 6: val_loss improved from 0.76971 to 0.52125, saving model to best_model_2.h5
# 378/378 - 192s - loss: 0.7386 - accuracy: 0.6898 - val_loss: 0.5212 - val_accuracy: 0.7773 - 192s/epoch - 509ms/step
# Epoch 7/30
#
# Epoch 7: val_loss did not improve from 0.52125
# 378/378 - 190s - loss: 0.7043 - accuracy: 0.7085 - val_loss: 1.2822 - val_accuracy: 0.5982 - 190s/epoch - 502ms/step
# Epoch 8/30
#
# Epoch 8: val_loss did not improve from 0.52125
# 378/378 - 190s - loss: 0.6914 - accuracy: 0.7204 - val_loss: 0.5273 - val_accuracy: 0.7411 - 190s/epoch - 502ms/step
# Epoch 9/30
#
# Epoch 9: val_loss did not improve from 0.52125
# 378/378 - 190s - loss: 0.6176 - accuracy: 0.7465 - val_loss: 0.5691 - val_accuracy: 0.7376 - 190s/epoch - 503ms/step
# Epoch 10/30
#
# Epoch 10: val_loss improved from 0.52125 to 0.46268, saving model to best_model_2.h5
# 378/378 - 197s - loss: 0.6096 - accuracy: 0.7434 - val_loss: 0.4627 - val_accuracy: 0.8016 - 197s/epoch - 520ms/step
# Epoch 11/30
#
# Epoch 11: val_loss did not improve from 0.46268
# 378/378 - 190s - loss: 0.6025 - accuracy: 0.7505 - val_loss: 0.5533 - val_accuracy: 0.7356 - 190s/epoch - 503ms/step
# Epoch 12/30
#
# Epoch 12: val_loss did not improve from 0.46268
# 378/378 - 189s - loss: 0.5818 - accuracy: 0.7609 - val_loss: 0.6199 - val_accuracy: 0.7480 - 189s/epoch - 501ms/step
# Epoch 13/30
#
# Epoch 13: val_loss did not improve from 0.46268
# 378/378 - 190s - loss: 0.5572 - accuracy: 0.7687 - val_loss: 0.5354 - val_accuracy: 0.7837 - 190s/epoch - 502ms/step
# Epoch 14/30
#
# Epoch 14: val_loss did not improve from 0.46268
# 378/378 - 189s - loss: 0.5831 - accuracy: 0.7616 - val_loss: 0.4948 - val_accuracy: 0.8026 - 189s/epoch - 501ms/step
# Epoch 15/30
#
# Epoch 15: val_loss improved from 0.46268 to 0.43315, saving model to best_model_2.h5
# 378/378 - 191s - loss: 0.5429 - accuracy: 0.7731 - val_loss: 0.4331 - val_accuracy: 0.8189 - 191s/epoch - 505ms/step
# Epoch 16/30
#
# Epoch 16: val_loss did not improve from 0.43315
# 378/378 - 190s - loss: 0.5178 - accuracy: 0.7755 - val_loss: 0.4915 - val_accuracy: 0.7713 - 190s/epoch - 504ms/step
# Epoch 17/30
#
# Epoch 17: val_loss did not improve from 0.43315
# 378/378 - 189s - loss: 0.6402 - accuracy: 0.7474 - val_loss: 5.5788 - val_accuracy: 0.2882 - 189s/epoch - 500ms/step
# Epoch 18/30
#
# Epoch 18: val_loss did not improve from 0.43315
# 378/378 - 190s - loss: 0.5791 - accuracy: 0.7664 - val_loss: 0.5412 - val_accuracy: 0.7758 - 190s/epoch - 502ms/step
# Epoch 19/30
#
# Epoch 19: val_loss did not improve from 0.43315
# 378/378 - 195s - loss: 0.5610 - accuracy: 0.7677 - val_loss: 0.5208 - val_accuracy: 0.7857 - 195s/epoch - 517ms/step
# Epoch 20/30
#
# Epoch 20: val_loss did not improve from 0.43315
# 378/378 - 190s - loss: 0.5099 - accuracy: 0.7948 - val_loss: 0.6987 - val_accuracy: 0.7341 - 190s/epoch - 502ms/step
# Epoch 21/30
#
# Epoch 21: val_loss did not improve from 0.43315
# 378/378 - 189s - loss: 0.5009 - accuracy: 0.7885 - val_loss: 0.5447 - val_accuracy: 0.7510 - 189s/epoch - 501ms/step
# Epoch 22/30
#
# Epoch 22: val_loss did not improve from 0.43315
# 378/378 - 189s - loss: 0.4846 - accuracy: 0.7965 - val_loss: 0.4835 - val_accuracy: 0.8046 - 189s/epoch - 501ms/step
# Epoch 23/30
#
# Epoch 23: val_loss did not improve from 0.43315
# 378/378 - 190s - loss: 0.4800 - accuracy: 0.7983 - val_loss: 0.8294 - val_accuracy: 0.7004 - 190s/epoch - 502ms/step
# Epoch 24/30
#
# Epoch 24: val_loss did not improve from 0.43315
# 378/378 - 196s - loss: 0.4819 - accuracy: 0.8047 - val_loss: 0.4491 - val_accuracy: 0.8095 - 196s/epoch - 517ms/step
# Epoch 25/30
#
# Epoch 25: val_loss did not improve from 0.43315
# 378/378 - 190s - loss: 0.4620 - accuracy: 0.8097 - val_loss: 0.4746 - val_accuracy: 0.8219 - 190s/epoch - 502ms/step
# Epoch 26/30
#
# Epoch 26: val_loss did not improve from 0.43315
# 378/378 - 195s - loss: 0.4374 - accuracy: 0.8113 - val_loss: 0.4576 - val_accuracy: 0.8160 - 195s/epoch - 517ms/step
# Epoch 27/30
#
# Epoch 27: val_loss did not improve from 0.43315
# 378/378 - 189s - loss: 0.4460 - accuracy: 0.8138 - val_loss: 0.4588 - val_accuracy: 0.8209 - 189s/epoch - 501ms/step
# Epoch 28/30
#
# Epoch 28: val_loss did not improve from 0.43315
# 378/378 - 191s - loss: 0.4351 - accuracy: 0.8186 - val_loss: 0.5222 - val_accuracy: 0.7822 - 191s/epoch - 505ms/step
# Epoch 29/30
#
# Epoch 29: val_loss improved from 0.43315 to 0.42294, saving model to best_model_2.h5
# 378/378 - 191s - loss: 0.4298 - accuracy: 0.8158 - val_loss: 0.4229 - val_accuracy: 0.8244 - 191s/epoch - 506ms/step
# Epoch 30/30
#
# Epoch 30: val_loss did not improve from 0.42294
# 378/378 - 189s - loss: 0.4263 - accuracy: 0.8198 - val_loss: 0.4341 - val_accuracy: 0.7892 - 189s/epoch - 501ms/step

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %%
def plot_hist(hist):
    plt.plot(hist.history["loss"])
    plt.plot(hist.history["val_loss"])
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()


plot_hist(hist)

# %%
model.save("model")
model.save("model.h5")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 130). These functions will not be directly callable after loading.

# %%
import shutil
shutil.make_archive('model', 'zip', 'model')
# Out:
# '/content/model.zip'
